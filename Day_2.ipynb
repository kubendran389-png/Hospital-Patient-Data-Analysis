# %% [markdown]
# <a href="https://colab.research.google.com/github/kubendran389-png/Hospital-Patient-Data-Analysis/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Welcome",name)
greet("Students")
# Out:
# Welcome Students

# %%
def greet():
  print("Hello")
greet()
# Out:
# Hello

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30

# %%
def calculate_average(a,b,c):
  return(a+b+c)
try:
  a=int(input("enter 1st number:"))
  b=int(input("enter 2st number:"))
  c=int(input("enter 3st number:"))
  print("calculate_average=",calculate_average(a,b,c))
except ValueError:
  print("invalid input")
# Out:
# enter 1st number:25
# enter 2st number:35
# enter 3st number:45
# calculate_average= 105
