# %% [markdown]
# <a href="https://colab.research.google.com/github/kubendran389-png/Hospital-Patient-Data-Analysis/blob/main/Attendence_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_average(a,b,c):
  return(a+b+c)
try:
  a=int(input("enter 1st number:"))
  b=int(input("enter 2st number:"))
  c=int(input("enter 3st number:"))
  print("calculate_average=",calculate_average(a,b,c))
except ValueError:
  print("invalid input")
# Out:
# enter 1st number:72
# enter 2st number:5
# enter 3st number:63
# calculate_average= 140
